# %%
# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np

# %%
#load model # Accuracy=99.73 , validation Accuracy = 89.44 # very light model, size =130MB
model = load_model("C:/Users/ADMIN/Downloads/dataset-20240727T170103Z-001/dataset/model/myface1model.h5") # cnn
 
# model accept below hight and width of the image
img_width, img_hight = 224,224

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#startt  web cam
cap = cv2.VideoCapture(0) # for webcam

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (255, 0, 0) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.1, 6) # 1.1, 3) for 1.mp4
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
        cv2.imwrite('C:/Users/ADMIN/Downloads/dataset-20240727T170103Z-001/dataset/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('C:/Users/ADMIN/Downloads/dataset-20240727T170103Z-001/dataset/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
        #print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (0, 255, 0)
            cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 255, 0), 3)
            cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA)
            cv2.imwrite('C:/Users/ADMIN/Downloads/dataset-20240727T170103Z-001/dataset/output/mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 0, 255)
            cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255,), 3)
            cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA)
            
            cv2.imwrite('C:/Users/ADMIN/Downloads/dataset-20240727T170103Z-001/dataset/output/withoutmask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        
        # Using cv2.putText() method 
         
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 192ms/step
# user not wearing mask - prob =  0.99561584
# 1/1 [==============================] - 0s 152ms/step
# user not wearing mask - prob =  0.9998721
# 1/1 [==============================] - 0s 205ms/step
# user not wearing mask - prob =  0.9993649
# 1/1 [==============================] - 0s 138ms/step
# user not wearing mask - prob =  0.99780995
# 1/1 [==============================] - 0s 145ms/step
# user not wearing mask - prob =  0.95914614
# 1/1 [==============================] - 0s 175ms/step
# user not wearing mask - prob =  0.80177355
# 1/1 [==============================] - 0s 131ms/step
# user not wearing mask - prob =  0.6967041
# 1/1 [==============================] - 0s 176ms/step
# user not wearing mask - prob =  0.9913925
# 1/1 [==============================] - 0s 135ms/step
# user not wearing mask - prob =  0.9954051
# 1/1 [==============================] - 0s 198ms/step
# user not wearing mask - prob =  0.9980027
# ...
